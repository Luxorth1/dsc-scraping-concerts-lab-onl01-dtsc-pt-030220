# %% [markdown]
# # Scraping Concerts - Lab
#
# ## Introduction
#
# Now that you've seen how to scrape a simple website, it's time to again practice those skills on a full-fledged site!
# In this lab, you'll practice your scraping skills on a music website: https://www.residentadvisor.net.
# ## Objectives
#
# You will be able to:
# * Create a full scraping pipeline that involves traversing over many pages of a website, dealing with errors and storing data

# %% [markdown]
# ## View the Website
#
# For this lab, you'll be scraping the https://www.residentadvisor.net website. Start by navigating to the events page [here](https://www.residentadvisor.net/events) in your browser.
#
# <img src="images/ra.png">

# %%
# Load the https://www.residentadvisor.net/events page in your browser.

# %% [markdown]
# ## Open the Inspect Element Feature
#
# Next, open the inspect element feature from your web browser in order to preview the underlying HTML associated with the page.

# %%
# Open the inspect element feature in your browser
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# ## Write a Function to Scrape all of the Events on the Given Page Events Page
#
# The function should return a Pandas DataFrame with columns for the Event_Name, Venue, Event_Date and Number_of_Attendees.

# %%
def scrape_events(events_page_url):
    #Your code here
    html_page = requests.get(events_page_url)
    soup = BeautifulSoup(html_page.content, 'html.parser')
    contentDiv = soup.find('div', class_="content clearfix")
    eventListing = contentDiv.find('div', id="event-listing")
    eventName = []
    venueName = []
    eventDate = []
    numAttendee = []
    eventName = [h1.find('a').attrs['title'] for h1 in eventListing.findAll('h1', class_="event-title")]
    eventName = [p[17:] for p in eventName]
    venueName = [div.find('span').text.strip() for div in eventListing.findAll('div', class_="bbox")]
    venueName = [p[3:] for p in venueName]
    eventDate = [span.find('time').text.strip() for span in eventListing.findAll('span', style="display:none;")]
    eventDate = [p[:-6] for p in eventDate]
    numAttendee = [p.find('span').text.strip() for p in eventListing.findAll('p', class_='attending')]
    df = pd.DataFrame([eventName, venueName, eventDate, numAttendee]).transpose()
    df.columns = ["Event_Name", "Venue", "Event_Date", "Number_of_Attendees"]
    return df
# scrape_events('https://www.residentadvisor.net/events/us/newyork/week/2020-04-07')
# Out:
#                                            Event_Name  \
# 0   Virtual Tuesday: Skillshare, Jadalareign, and ...
# 1   Virtual Wednesday: Planetarium with DJ Python ...
# 2   Passover Seders - NYC Kosher Restaurants - Tal...
# 3                                         Arthur Moon
# 4   Caspian with Pianos Become The Teeth and Maserati
# 5                  Postponed / Open Decks Session 107
# 6                  Seven Davis Jr. presents 'Friends'
# 7   Passover Seders - NYC Kosher Restaurants - Tal...
# 8   Virtual Thursday: Seltzer with Bearcat, Precol...
# 9                               Anything Goes: Demuir
# 10                                         Kiana Ledé
# 11            Dis Fig & King Vision Ultra [POSTPONED]
# 12  [CANCELED] Dixon, Kim Ann Foxman, Pablo Romero...
# 13                            Paco Osuna - Openxclose
# 14  *Postponed* BAE presents: Ancient Sounds x Fut...
# 15                   The Thrillseekers present: Hydra
# 16                     Zaltan, Yu Su, Tal [POSTPONED]
# 17                                     The Glitch Mob
# 18  Despacito with Beau Wanzer, Deep Creep, Hank J...
# 19  Passover Seders - NYC Kosher Restaurants - Tal...
# 20  Toyota with dj Maui Babe at Nyias 2020 - Postp...
# 21  Virtual Friday: Olive T and Peach b2b Shanti C...
# 22  [CANCELED] Elevation x Spotlight Series presen...
# 23             Cuff x Raw Phonics: Amine Edge & Dance
# 24                                    Chus & Ceballos
# 25  Pegboard Nerds - Heart of the Universe Part II...
# 26                          Whiskey Disco - Cancelled
# 27       Sonic Messengers: Savile & AceMo [POSTPONED]
# 28  Passover Seders - NYC Kosher Restaurants - Tal...
# 29                               Neon Indian - DJ SET
# 30  Update!: Toyota with dj Maui Babe at Nyias - P...
# 31   Sleepy & Boo and Guests - Water Tower Bar - Free
# 32             Virtual Saturday: Boo Lean and Om Unit
# 33   The Office presents: RAW Music By: Special Guest
# 34  [POSTPONED] Teksupport: MR G, Kenny Larkin & K...
# 35                  Dope Jams Spring Ball [POSTPONED]
# 36  Passover Seders - NYC Kosher Restaurants - Tal...
# 37  Update!: Toyota with dj Maui Babe at Nyias - P...
# 38             Virtual Saturday: Boo Lean and Om Unit
# 39                     Virtual Sunday: Optimo All Day
# 40         LPR Presents: Ed Balloon with Caine Casket
#
#                                 Venue  Event_Date Number_of_Attendees
# 0                            Nowadays  2020-04-07                   1
# 1                            Nowadays  2020-04-08                  18
# 2                  Talia's Steakhouse  2020-04-08                   4
# 3                      public records  2020-04-08                   1
# 4                    Le Poisson Rouge  2020-04-08                   5
# 5                                Eris  2020-04-08                   4
# 6                  Chelsea Music Hall  2020-04-09                   4
# 7                  Talia's Steakhouse  2020-04-09                   1
# 8                            Nowadays  2020-04-09                   3
# 9                               1 Oak  2020-04-09                 309
# 10                   Le Poisson Rouge  2020-04-09                  28
# 11                     public records  2020-04-09                   3
# 12                          Good Room  2020-04-10                   1
# 13                            Quantum  2020-04-10                  16
# 14                    The Sultan Room  2020-04-10                   7
# 15                     TBA - New York  2020-04-10                   5
# 16                     public records  2020-04-10                   4
# 17                     Brooklyn Steel  2020-04-10                  10
# 18                          Mood Ring  2020-04-10                   9
# 19                 Talia's Steakhouse  2020-04-10                   4
# 20  Jacob K. Javits Convention Center  2020-04-10                   1
# 21                           Nowadays  2020-04-10                  11
# 22                     TBA - New York  2020-04-10                   4
# 23                       Bogart House  2020-04-11                   4
# 24                      3 Dollar Bill  2020-04-11                   2
# 25                  Hornblower Cruise  2020-04-11                  12
# 26                       House Of Yes  2020-04-11                   4
# 27                     public records  2020-04-11                   2
# 28                 Talia's Steakhouse  2020-04-11                   1
# 29                         Schimanski  2020-04-11                None
# 30  Jacob K. Javits Convention Center  2020-04-11                None
# 31                The Water Tower Bar  2020-04-11                None
# 32                           Nowadays  2020-04-11                None
# 33                     TBA - New York  2020-04-11                None
# 34                       99 Scott Ave  2020-04-11                None
# 35                     public records  2020-04-12                None
# 36                 Talia's Steakhouse  2020-04-12                None
# 37  Jacob K. Javits Convention Center  2020-04-12                None
# 38                           Nowadays  2020-04-12                None
# 39                           Nowadays  2020-04-12                None
# 40                   Baby's All Right  2020-04-13                None

# %% [markdown]
# ## Write a Function to Retrieve the URL for the Next Page

# %%
#if you are URL hacking you need to set var 'todayDate' to current day of month, may not work if you go past 1 year
def next_page(url):
    #Your code here
    html_page = requests.get(url)
    soup = BeautifulSoup(html_page.content, 'html.parser')
    next_button = soup.find('li', id='liNext')
    if next_button:
        return next_button.find('a').attrs['href']
    else:
        return None
next_page('https://www.residentadvisor.net/events/us/newyork/week/2020-04-14')
# Out:
# '/events/us/newyork/week/2020-04-21'

# %% [markdown]
# ## Scrape the Next 1000 Events for Your Area
#
# Display the data sorted by the number of attendees. If there is a tie for the number attending, sort by event date.

# %%
#Your code here
import time
def parseData(iterations):
#     eventName, venueName, eventDate, numAttendee
    finalDF = []
    total_rows = 0
    url = 'https://www.residentadvisor.net/events'
    next_url = ''
    while total_rows <= iterations:
        if total_rows == 0:
            url = 'https://www.residentadvisor.net/events'
            next_url = next_page(url)
            df = scrape_events(url)
            finalDF.append(df)
            total_rows += len(df)
            time.sleep(.2)
        else:
            url = 'https://www.residentadvisor.net' + next_url
            next_url = next_page(url)
            df = scrape_events(url)
            finalDF.append(df)
            total_rows += len(df)
            time.sleep(.2)
    df = pd.concat(finalDF)
    return len(df)
    
parseData(200)
# Out:
# 201

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-2108d0e747b9> in <module>
# ----> 1 URL = self.request.GET
#
# NameError: name 'self' is not defined

# %% [markdown]
# ## Summary
#
# Congratulations! In this lab, you successfully developed a pipeline to scrape a website for concert event information!
